# %%
# Aquí se encuentra los ejercicios de clase y los de práctiva python 1

nota = 4.2

if nota>= 4.5:
    print ("la nota")
    print("Excelente")
elif nota >= 4.0:
    print ("Muy buen desempeño")
elif nota >= 3.0:
    print ("Aprobado")
else:
    print ("No aprobado")
# Out:
# Muy buen desempeño

# %%
nota = 4.2

if nota>= 3.0:
    print("Aprobado")
elif nota >= 4.0:
    print ("Muy buen desempeño")
elif nota >= 4.5:
    print ("Excelente")
else:
    print ("No aprobado")

# %%
usuario_activo = True
tiene_permiso = True

if usuario_activo and tiene_permiso:
    print ("Acceso permitido")
else:
    print ("Acceso denegado")
# Out:
# Acceso denegado

# %%
for numero in range(1,8):

    if numero<3:
        print(numero,"A")
    elif numero<6:
        print(numero,"B")
    else:
        print(numero,"C")
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %%
for i in range(5):

    #t=float(input('Temperatura: '))
    t=float(input('Temperatura: '))

    if t <18:
        print('Temperatura baja')
    elif t <= 25:
        print('Temperatura normal')
    else:
        print('Temperatura alta')
# Out:
# Temperatura: 10
# Temperatura baja
# Temperatura: 30
# Temperatura alta
# Temperatura: 18
# Temperatura normal
# Temperatura: 25
# Temperatura normal
# Temperatura: 40
# Temperatura alta

# %%
#1 Completa una decisión simple

edad = 20
if edad >= 18:
    print("Mayor de edad")
else:
    print("Menor de edad")
# Out:
# Mayor de edad

# %%
# 2 Agrega la ruta alternativa

temperatura = 32

if temperatura > 30:
    print("Alta")
else:
    print("Temperatura normal")
# Out:
# Alta

# %%
# 3 Predice la salida

numero = 7

if numero % 2 == 0:
    print("Par")
else:
    print("Impar")
# Out:
# Impar

# %%
# 4 Completa la clasificación

nota = 4.2

if nota>= 4.5:
    print("Excelente")
elif nota >= 4.0:
    print("Muy buen desempeño")
elif nota >= 3.0:
    print("Aprobado")
else:
    print("No aprobado")
# Out:
# Muy buen desempeño

# %%
# 5 Corrige el orden

nota = 4.8

if nota >= 4.5:
    print("Excelente")
elif nota >= 4.0:
    print("Muy buen desempeño")
elif nota >= 3.0:
    print("Aprobado")
else:
    print("No aprobado")
# Out:
# Excelente

# %%
#6 Traza la ejecución

valor = 2

if valor >= 15:
    print ("A")
elif valor >= 10:
    print ("B")
elif valor >= 5:
    print ("C")
else:
    print("D")
# Out:
# D

# %%
# C Operadores lógicos
#7 Acceso con dos requisitos

usuario_activo = True
tiene_permiso = True

if usuario_activo and tiene_permiso:
    print ("Acceso permitido")
else:
    print ("Acceso denegado")
# Out:
# Acceso permitido

# %%
#8 Dos rutas válidas

correo_valido = False
telefono_valido = True

if correo_valido and telefono_valido:
    print ("Continuar registro")
else:
    print ("Faltan datos de contacto")
# Out:
# Faltan datos de contacto

# %%
#9 Usa negación

cuenta_bloqueada = False

if not cuenta_bloqueada:
    print ("Puede operar")
else:
    print ("No puede operar")
# Out:
# No puede operar

# %%
#10 Recorre del 1 al 5

for numero in range(1,6):
    print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#11 Recorre con paso

for numero in range(2,11,2):
    print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# 12 Predice el acumulado

suma = 0

for i in range(1,4):
    suma = suma + i
    print(suma)
# Out:
# 1
# 3
# 6

# %%
#13 Completa el contador

numero = 2

while numero <= 10:
    print (numero)
    numero = numero + 2
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# 14 encuentra el ciclo infinito

numero = 1

while numero <= 5:
    print (numero)
    numero = numero + 1

# %%
# 15 Control de intentos
intentos = 0
while intentos <3:
  clave = input("Ingrese la clave: ")
  intentos = intentos + 1
print("Proceso finalizado")
# Out:
# Ingrese la clave: 1020
# Ingrese la clave: 1120
# Ingrese la clave: 1020
# Proceso finalizado

# %%
# Elegir y combinar estructuras
#16. For o While

# Procesar exactamente 10 mediciones --> for
# Pedir una clave hasta que sea correcta --> while
# Imprimir los números del 1 al 20 --> for
# Repetir un cálculo hasta que el error sea menor que 0.01---> while

# %%
# 17. Combina for + if
#Completa el programa para recorrer del 1 al 12 y mostrar únicamente los múltiplos de 3.

for numero in range(1,13):
  if numero % 3 == 0:
    print(numero)
# Out:
# 3
# 6
# 9
# 12

# %%
#18 Predice antes de ejecutar
#Escribe todas las líneas que producirá el programa.
for numero in range(1, 8):
    if numero < 3:
        print(numero, "A") # para A imprimira 1 y 2
    elif numero < 6:
        print(numero, "B") # para B imprimirá 3 al 5
    else:
        print(numero, "C") # para C imprimirá 6 y 7. 8 no porque es hasta -1
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %%
# 19 Traduce una decisión

#Completa el código Python para que represente exactamente el pseudocódigo mostrado.
#PSEUDOCÓDIGO
#LEER nota
#SI nota >= 3.0 ENTONCES
#ESCRIBIR "Aprobado"
#SI NO
#ESCRIBIR "No aprobado"
#FIN SI
#PYTHON

nota = float(input("Nota: "))
if nota >= 3.0:
    print("Aprobado")
else:
    print("No aprobado")

# %%
# 20 traduce una repetición

#Completa el programa Python equivalente al pseudocódigo.
#PSEUDOCÓDIGO
#PARA i DESDE 1 HASTA 5 HACER
#ESCRIBIR i
#FIN PARA
#PYTHON
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Reto -  Clasificación de temperaturas
#Completa todos los espacios. Antes de ejecutar, prueba mentalmente tu solución con los
#valores: 15, 18, 22, 25 y 30.

# El programa debe solicitar 5 temperaturas.
# Para cada una debe mostrar:
# "Baja" si t < 18
# "Normal" si 18 <= t <= 25
# "Alta" si t > 25
for t in range(18,26):
    t = float(input("Temperatura: "))
    if t < 18:
      print("Baja")
    elif t <=25:
      print("Normal")
    else:
      print("Alta")
# Out:
# Temperatura: 15
# Baja
# Temperatura: 19
# Normal
# Temperatura: 24
# Normal
# Temperatura: 25
# Normal
# Temperatura: 26
# Alta
# Temperatura: 14
# Baja
# Temperatura: 22
# Normal
# Temperatura: 30
# Alta
